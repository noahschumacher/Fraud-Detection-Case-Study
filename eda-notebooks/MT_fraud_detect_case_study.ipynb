# %%
import pandas as pd

# %%
df = pd.read_json('data/data/data.json')

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
enent created aprox payout data 
event crated compare to even published

# %%
df['description'];

# %%
plt.hist(df.user_age)

# %%
df.user_age.unique()
# Out:
# array([  36,  149,  214, ..., 3561, 3689, 1775], dtype=int64)

# %%
df.previous_payouts[1]
# Out:
# [{'name': 'RUF',
#   'created': '2010-10-01 01:10:09',
#   'country': 'US',
#   'amount': 34389.38,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 786869,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-02-02 01:12:10',
#   'country': 'US',
#   'amount': 764.93,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 786878,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-03-15 01:30:42',
#   'country': 'US',
#   'amount': 17405.26,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 1181203,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-03-15 01:30:42',
#   'country': 'US',
#   'amount': 2224.16,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 1293213,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-04-01 01:30:31',
#   'country': 'US',
# ...

# %%
df.payout_type.value_counts()
# Out:
# ACH      10666
# CHECK     3178
#            493
# Name: payout_type, dtype: int64

# %%
df.sale_duration;

# %%
df.sale_duration2;

# %%
df.currency.value_counts()
# Out:
# USD    9696
# GBP    2222
# CAD    1322
# AUD     779
# EUR     262
# NZD      55
# MXN       1
# Name: currency, dtype: int64

# %%
df[(df['payout_type'] != 'ACH') & (df['payout_type'] != 'CHECK')]
# Out:
#              acct_type  approx_payout_date  body_length  channels country  \
# 0      fraudster_event          1266062400         3852         5      US
# 183          fraudster          1341198000          695        12      US
# 187    fraudster_event          1354838400         2805         8      CA
# 212    fraudster_event          1353477600            0         5      US
# 219    fraudster_event          1348916400            0        11      US
# 289    fraudster_event          1359676800            0         0      MY
# 296    fraudster_event          1360881000         3657         5      GB
# 307    fraudster_event          1359698400          115         0      GB
# 330    fraudster_event          1364706000           75         0      US
# 440    fraudster_event          1372312800         1351         5      AU
# 451    fraudster_event          1377219600          533         6      PK
# 457    fraudster_event          1377061200            0         0      MA
# ...

# %%
df = pd.concat([df, pd.get_dummies(df.currency)], axis=1);

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 51 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
X = ['','','','']

# %%
df.acct_type.unique()
# Out:
# array(['fraudster_event', 'premium', 'spammer_warn', 'fraudster',
#        'spammer_limited', 'spammer_noinvite', 'locked', 'tos_lock',
#        'tos_warn', 'fraudster_att', 'spammer_web', 'spammer'],
#       dtype=object)

# %%
df.body_length; #Lets hold it for now since it might be associated with length of text

# %%
df.channels.value_counts()  #hold
# Out:
# 8     3364
# 0     2941
# 5     2459
# 11    2312
# 6     1736
# 4      556
# 12     470
# 10     237
# 13     232
# 9       20
# 7       10
# Name: channels, dtype: int64

# %%
df.delivery_method.value_counts()
# Out:
# 0.0    8520
# 1.0    5554
# 3.0     247
# Name: delivery_method, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(df.delivery_method)], axis=1);

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df.description[1]
# Out:
# '<p>Join us for a quick, one-night, community-building trip to Charleston, SC.</p>\r\n<p><strong>COST:</strong></p>\r\n<p>The trip costs a total of $35, which includes breakfast and lunch on Saturday and housing. You will be responsible to pay for your own dinner on Friday and Saturday. Early Bird tickets are available until noon on January 20 and include a great Winter Getaway T-Shirt. So don\'t wait to register!</p>\r\n<p>Registration ends at noon on January 27.</p>\r\n<p>A <em>very limited number</em> of scholarships are available. Contact your campus minister as soon as possible to see if you qualify.</p>\r\n<p><strong>TRANSPORTATION:</strong></p>\r\n<p>We are working to secure two fifteen passenger buses, which will be filled on a first-come, first-served basis. Payment must be received before a slot on a bus can be reserved. You will be responsible for your own transportation if a bus slot is not available.</p>\r\n<p><strong>WHAT TO BRING:</strong></p>\r\n<p>We will be staying 
# ...

# %%
df.email_domain.value_counts();   #hold

# %%
import matplotlib.pyplot as plt
plt.hist(df.event_end - df.event_created)
# Out:
# (array([1.3985e+04, 3.0300e+02, 3.5000e+01, 7.0000e+00, 5.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-5.33170000e+04,  1.89519640e+07,  3.79572450e+07,  5.69625260e+07,
#          7.59678070e+07,  9.49730880e+07,  1.13978369e+08,  1.32983650e+08,
#          1.51988931e+08,  1.70994212e+08,  1.89999493e+08]),
#  <a list of 10 Patch objects>)

# %%
## event transacation diff 
df['eventdiff'] = df['event_end'] - df['event_created']  #We get the diff in time bw transaction start and end

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
#df.gts.value_counts()
plt.hist(df.gts)
# Out:
# (array([1.4161e+04, 1.1900e+02, 2.8000e+01, 1.1000e+01, 7.0000e+00,
#         5.0000e+00, 3.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([     0.   ,  30629.393,  61258.786,  91888.179, 122517.572,
#         153146.965, 183776.358, 214405.751, 245035.144, 275664.537,
#         306293.93 ]),
#  <a list of 10 Patch objects>)

# %%
df.columns
# Out:
# Index([         'acct_type', 'approx_payout_date',        'body_length',
#                  'channels',            'country',           'currency',
#           'delivery_method',        'description',       'email_domain',
#             'event_created',          'event_end',    'event_published',
#               'event_start',       'fb_published',                'gts',
#             'has_analytics',         'has_header',           'has_logo',
#                    'listed',               'name',        'name_length',
#                 'num_order',        'num_payouts',          'object_id',
#                  'org_desc',       'org_facebook',           'org_name',
#               'org_twitter',         'payee_name',        'payout_type',
#          'previous_payouts',      'sale_duration',     'sale_duration2',
#                  'show_map',       'ticket_types',           'user_age',
#              'user_created',          'user_type',      'venue_address',
# ...

# %%
df.name #hold NLP
df.num_payouts.value_counts()   #Number of times credit card has been used
df.object_id.value_counts()  #id of trasaction hold
df.org_desc
df.org_facebook #hold NLP
df.name_length.value_counts();

# %%
len(df.name[0])
# Out:
# '99 HOUR "NO SLEEP" SUPER BOWL CELEBRITY WEEKEND GRAND FINALE'

# %%
len(df.name[0])
# Out:
# 60

# %%
df.name_length;

# %%
plt.hist(df.num_payouts)
# Out:
# (array([1.373e+04, 3.070e+02, 1.030e+02, 6.400e+01, 4.100e+01, 4.100e+01,
#         3.500e+01, 7.000e+00, 7.000e+00, 2.000e+00]),
#  array([   0. ,  185.8,  371.6,  557.4,  743.2,  929. , 1114.8, 1300.6,
#         1486.4, 1672.2, 1858. ]),
#  <a list of 10 Patch objects>)

# %%
df.payout_type.value_counts()
# Out:
# ACH      10666
# CHECK     3178
#            493
# Name: payout_type, dtype: int64

# %%
df[(df['payout_type'] != 'ACH') & (df['payout_type'] != 'CHECK')]  #can't use since it is classified after target
#correlation does not imply causation
# Out:
#              acct_type  approx_payout_date  body_length  channels country  \
# 0      fraudster_event          1266062400         3852         5      US
# 183          fraudster          1341198000          695        12      US
# 187    fraudster_event          1354838400         2805         8      CA
# 212    fraudster_event          1353477600            0         5      US
# 219    fraudster_event          1348916400            0        11      US
# 289    fraudster_event          1359676800            0         0      MY
# 296    fraudster_event          1360881000         3657         5      GB
# 307    fraudster_event          1359698400          115         0      GB
# 330    fraudster_event          1364706000           75         0      US
# 440    fraudster_event          1372312800         1351         5      AU
# 451    fraudster_event          1377219600          533         6      PK
# 457    fraudster_event          1377061200            0         0      MA
# ...

# %%
df.previous_payouts[1]
# Out:
# [{'name': 'RUF',
#   'created': '2010-10-01 01:10:09',
#   'country': 'US',
#   'amount': 34389.38,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 786869,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-02-02 01:12:10',
#   'country': 'US',
#   'amount': 764.93,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 786878,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-03-15 01:30:42',
#   'country': 'US',
#   'amount': 17405.26,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 1181203,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-03-15 01:30:42',
#   'country': 'US',
#   'amount': 2224.16,
#   'state': 'GA',
#   'address': '1700 North Brown Road',
#   'uid': 5419068,
#   'event': 1293213,
#   'zip_code': '30043'},
#  {'name': 'RUF',
#   'created': '2011-04-01 01:30:31',
#   'country': 'US',
# ...

# %%
df.previous_payouts[1][0]['state']
# Out:
# 'RUF'

# %%
df.payee_name.value_counts();   #payee name will be empty if it is most likely to be fraud since at CC transaction it has to have a pruchaser and payee assigned

# %%
df.ticket_types[0]
# Out:
# [{'event_id': 527017,
#   'cost': 25.0,
#   'availability': 1,
#   'quantity_total': 800,
#   'quantity_sold': 0},
#  {'event_id': 527017,
#   'cost': 50.0,
#   'availability': 1,
#   'quantity_total': 100,
#   'quantity_sold': 0},
#  {'event_id': 527017,
#   'cost': 550.0,
#   'availability': 1,
#   'quantity_total': 20,
#   'quantity_sold': 0}]

# %%
df.venue_state
# Out:
# 0                         FL
# 1                         SC
# 2                         CA
# 3                       None
# 4                         MA
# 5                         KY
# 6                         MD
# 7                         NC
# 8
# 9                         NC
# 10
# 11
# 12                        TX
# 13                        CA
# 14                        CA
# 15                        NY
# 16                        MA
# 17                        ME
# 18
# 19                        CA
# 20
# 21                        TX
# 22                        MI
# 23                        AZ
# 24                        CA
# 25                        MN
# 26                        NY
# 27                        IL
# 28                        TX
# 29                        CA
#                 ...
# 14307
# 14308                     NC
# 14309
# 14310                     CA
# 14311                     CA
# 14312                     IL
# 14313
# 14314                     ON
# ...
